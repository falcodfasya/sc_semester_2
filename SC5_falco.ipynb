# %% [markdown]
# <a href="https://colab.research.google.com/github/falcodfasya/sc_semester_2/blob/main/SC5_falco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-poster')
#untuk mengatur gaya dari grafiknya

# %matplotlib inline
#untuk menampilkan grafik

h = 0.2
#h adalah jarak atau selisih antar x
x = np.arange(0, 2*np.pi, h)
#Membuat array x dari 0 sampai 2π dengan jarak antar elemen sebesar h. Ini adalah domain dari fungsi.
y = np.cos(x)
#hitung nilai cos(x) dalam tiap titik dalam array

forward_diff = np.diff(y)/h
#hitung turunan dengan metode forward difference
x_diff = x[:-1]
#Karena hasil forward_diff lebih pendek satu elemen daripada x, maka kita buang titik terakhir dari x agar cocok ukurannya untuk plotting.

exact_solution = -np.sin(x_diff)
#Menghitung turunan eksak dari cos⁡(𝑥), yaitu −sin(x), pada titik-titik yang sesuai (x_diff).

#untuk membuat grafik nya menggunakan garis "--" untuk numerik
plt.figure(figsize = [12, 8])
plt.plot(x_diff, forward_diff,'--', label = 'Finite difference approx')
plt.plot(x_diff, exact_solution, label = 'Exact Solution')
plt.legend()
plt.show()

#Menghitung galat maksimum (maximum error) antara hasil pendekatan
#numerik dan solusi eksak. Galat dihitung sebagai selisih absolut maksimum dari kedua array tersebut.
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.09966711079379187

# %%
#rieman

import numpy as np
def f(x):
  return 4*x**4 + 2*x**3 - 6*x

#left rieman
a = - 3
b = 3
n = 30

lebar = (b-a) / (n-1)
x = np.linspace(a, b, n)
y = f(x)

left_rieman = lebar * np.sum(y[:-1])
print (left_rieman)

#right rieman

a = - 3
b = 3
n = 30

lebar = (b-a) / (n-1)
x = np.linspace(a, b, n)
y = f(x)

right_rieman = lebar * np.sum(y[1:])
print (right_rieman)
# Out:
# 384.4323034267851
# 399.3288551509231

# %%
#middle rieman

a = - 3
b = 3
n = 30

lebar = (b-a) / (n-1)
x_mid = (x[:n-1] + x[1:])/2
y_mid = f(x_mid)

middle_rieman = lebar * np.sum(y_mid)
print (middle_rieman)

#trapezoid

a = - 3
b = 3
n = 30

lebar = (b-a) / (n-1)
x_mid = (x[:n-1]+x[1:])/2
y_mid = f(x_mid)

trapezoid = (lebar*y[0] + y[n-1] + 2*np.sum(y_mid))
print (trapezoid)
# Out:
# 387.26026006636687
# 4163.1020542047645

# %%
#simpsons rule

a = 0
b = np.pi
n = 10
h = (b-a) / n
x = np.linspace(a, b, n+1)
y = np.sin(x)

s = h/3 * (y[0] + y[-1] + 4*np.sum(y[1:-1:2]) + 2*np.sum(y[2:-2:2]))
exact = 2

error = abs (s-exact)
print ("simpsons = ", s)
print ("exact = ", exact)
print ("error = ", error)
# Out:
# simpsons =  2.0001095173150043
# exact =  2
# error =  0.00010951731500430384

# %% [markdown]
# MODUL 5

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 0.1, 0.2, 0.3, 0.4])
y = np.array([0, 0.0819, 0.01341, 0.1646, 0.1797])
h = 0.1

# Forward difference x = 0
dy_dx_forward = (y[1] - y[0]) / h

# Central difference x = 0.2
dy_dx_central = (y[3] - y[1]) / (2*h)

print(f" x=0 : {dy_dx_forward}")
print(f" x=0.2 : {dy_dx_central}")
# Out:
#  x=0 : 0.819
#  x=0.2 : 0.4135

# %%
def f(x):
    return np.sin(x)

a = 0
b = np.pi

#  8 panel
n1 = 8
h1 = (b - a) / n1
x1 = np.linspace(a, b, n1 + 1)
y1 = f(x1)
trapz_8 = h1 * (y1[0] + 2 * sum(y1[1:-1]) + y1[-1]) / 2
print(f"8 panel: {trapz_8}")

# 16 panel
n2 = 16
h2 = (b - a) / n2
x2 = np.linspace(a, b, n2 + 1)
y2 = f(x2)
trapz_16 = h2 * (y2[0] + 2 * sum(y2[1:-1]) + y2[-1]) / 2
print(f"16 panel: {trapz_16}")
# Out:
# 8 panel: 1.9742316019455508
# 16 panel: 1.9935703437723395

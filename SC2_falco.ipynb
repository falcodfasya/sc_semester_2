# %% [markdown]
# <a href="https://colab.research.google.com/github/falcodfasya/sc_semester_2/blob/main/SC2_falco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = [[8, 3, -3], [-2,-8,5],[3,5,10]]

#Find diagonal coefficients
diag = np.diag(np.abs(a))


#find row sum without diagonal

off_diag = np.sum(np.abs(a), axis = 1) - diag
if np.all(diag > off_diag):
  print('matrix is diagonaly dominant')
else:
  print('not diagonaly dominant')
# Out:
# matrix is diagonaly dominant

# %%
x1 = 0
x2 = 0
x3 = 0

epsilon = 0.01
converged = False

x_old = np.array([x1,x2,x3])

for k in range (1,50):
  x1 = (14 - 3*x2 + 3*x3) / 8
  x2 = (5 + 2*x1 - 5*x3) / (-8)
  x3 = (-8 - 3*x1 - 5*x2) / (10)
  x_new = np.array([x1,x2,x3])
  dx = np.sqrt (np.dot(x_new - x_old , x_new - x_old))

  print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))

  if dx < epsilon :
    converged = True
    print("converged")
    break

  x_old = x_new

if not converged :
  print("bebas lah")
# Out:
# 1, 1.7500, -1.0625, -0.7937
# 2, 1.8508, -1.5838, -0.5633
# 3, 2.1327, -1.5103, -0.6847
# 4, 2.0596, -1.5678, -0.6340
# 5, 2.1002, -1.5463, -0.6569
# 6, 2.0835, -1.5565, -0.6468
# 7, 2.0911, -1.5520, -0.6513
# converged

# %%
import numpy as np

# %%
# Define matrix A and Vector y

A = np.array ([[4,3,5], [-2,-4,5], [ 8,8,0]])
y = np.array ([2,5,-3])

#solve for x
x = np.linalg.solve(A,y)

#prinr the solution
print(x)
# Out:
# [ 0.375 -0.75   0.55 ]

# %%
import numpy as nump
from scipy import optimize
import matplotlib.pyplot as plt

# Define matrix A and Vector y

A = np.array ([[4,3,-5], [-2,-4,5], [ 8,8,0]])
y = np.array ([2,5,-3])

# find the inverse of A

A_inv = np.linalg.inv(A)

#multiply the inverse by y to get the slution

x = np.dot(A_inv,y)

#print
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
import numpy as nump
from scipy import optimize
import matplotlib.pyplot as plt

#generate x dan y

x = np.linspace(0,1,101)
y = 1 + x + x * np.random.random(len(x))

#assemble matrix A
A = np.vstack([x,np.ones(len(x))]).T

#turn Y into coulm vector I

y = y[:,np.newaxis]

#Direct least square regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.54574087]
#  [0.96881403]]

# %%
import numpy as nump
import matplotlib.pyplot as plt

# %%
#plot the data the regression line

plt.figure(figsize=(10,8))
plt.plot(x,y,'b.', label = 'Data')
plt.plot(x,alpha[0]*x + alpha[1], 'r', label = 'Fit')
plt.xlabel('x')
plt.ylabel('y')
3.00
plt.show()

# %%
#generate x dan y

x = np.linspace(0,1,101)
y = 1 + x + x * np.random.random(len(x))

#assemble matrix A
A = np.vstack([x,np.ones(len(x))]).T

#turn Y into coulm vector I

y = y[:,np.newaxis]

# calculate pseudoinvers

pinv= np.linalg.pinv(A)

#compute the solution

alpha = pinv.dot(y)

#print the confficient
print(alpha)
# Out:
# [[1.40021438]
#  [1.04150731]]

# %%
#generate x dan y

x = np.linspace(0,1,101)
y = 1 + x + x * np.random.random(len(x))

#Define the model function
def func(x , a, b):
  return a * x + b

#Use curve fitting to find the best parameters
alpha, _ = optimize.curve_fit(func, x, y)

print(alpha)
# Out:
# [1.50786101 0.98806599]

# %%
import numpy as nump
import matplotlib.pyplot as plt

# %%
x = [3,1,2,3]
y = [5,1,4,9]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range("1/1/2000",periods =1000))
ts = ts.cumsum()
ts.plot();

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [1,2,3,4,5,6,7,8]
y = [2,5,1,7,9,3,6,10]

x = np.array (x)
y = np.array (y)

plt.plot ( x,y, 'ob')
#o = bentuk
#b = blue

plt.plot(x,y,'r--')
#-- = garis putus putus

plt.plot(x , 2*x + 1,'g')

plt.title("basic Plotting")
plt.ylabel("Y")
plt.xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Buat index waktu
index = pd.date_range(start="2005-01-01", periods=10000, freq="D")

# Buat DataFrame
df = pd.DataFrame(np.random.randn(10000, 4), index=index, columns=list("ABCD"))
df = df.cumsum()  # Melakukan kumulatif sum

# Plot data dengan benar
plt.figure()
df.plot()
plt.show()

# %%
#Soal nomor 1 A

import numpy as np

a = [[2, 3, -1], [1,-1,2],[3,2,1]]

diag = np.diag(np.abs(a))

off_diag = np.sum(np.abs(a), axis = 1) - diag
if np.all(diag > off_diag):
  print('matrix is diagonaly dominant')
else:
  print('not diagonaly dominant')
# Out:
# not diagonaly dominant

# %%
import numpy as np

# %%
x= 5
y = 5
z = 5

epsilon = 0.001
converged = False

x_old = np.array([x,y,z])

for k in range (1,50):
  x1 = (10 + 3*y - 1*z) / (2)
  x2 = (4 + 1*x + 2*z) / (1)
  x3 = (14 + 3*x + 2*y) / (1)
  x_new = np.array([x1,x2,x3])
  dx = np.sqrt (np.dot(x_new - x_old , x_new - x_old))

  print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))

  if dx < epsilon :
    converged = True
    print("converged")
    break

  x_old = x_new

if not converged :
  print("bebas lah wong ora converged")

#B
import numpy as nump

A = np.array ([[2, 3, -1], [1,-1,2],[3,2,1]])
y = np.array ([10,4,14])

# find the inverse of A

A_inv = np.linalg.inv(A)

x = np.dot(A_inv,y)

print(x)

#B2
A = np.array ([[2, 3, -1], [1,-1,2],[3,2,1]])
y = np.array ([10,4,14])

A_inv = np.linalg.inv(A)

x = np.dot(A_inv,y)

print(x)
# Out:
# 1, 10.0000, 19.0000, 39.0000
# 2, 10.0000, 19.0000, 39.0000
# converged
# [ 0.   3.5 -0.5]
# [ 0.   3.5 -0.5]

# %%
x= 1
y = 2
z = 3

epsilon = 0.001
converged = False

x_old = np.array([x,y,z])

for k in range (1,50):
  x1 = (7.85 - 0.1*y - 0.2*z) / (3)
  x2 = (-19.3 + 0.1*x - 0.3*z) / (7)
  x3 = (71.4 + 3*x - 0.2*y) / (10)
  x_new = np.array([x1,x2,x3])
  dx = np.sqrt (np.dot(x_new - x_old , x_new - x_old))

  print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))

  if dx < epsilon :
    converged = True
    print("converged")
    break

  x_old = x_new

if not converged :
  print("bebas lah wong ora converged")

#B
import numpy as nump

A = np.array ([[3, -0.1, -0.2], [0.1,7,0.3],[3,-0.2,10]])
y = np.array ([7.85,-19.3,71.4])

# find the inverse of A

A_inv = np.linalg.inv(A)

x = np.dot(A_inv,y)

print(x)

#B2
A = np.array ([[3, -0.1, -0.2], [0.1,7,0.3],[3,-0.2,10]])
y = np.array ([7.85,-19.3,71.4])

A_inv = np.linalg.inv(A)

x = np.dot(A_inv,y)

print(x)
# Out:
# 1, 2.3500, -2.8714, 7.4000
# 2, 2.3500, -2.8714, 7.4000
# converged
# [ 2.92786645 -3.06469864  6.20034609]
# [ 2.92786645 -3.06469864  6.20034609]

# %%
import numpy as nump
from scipy import optimize
import matplotlib.pyplot as plt

#generate x dan y

x = np.array([5,4,6,7,5])
y = np.array([10,8,12,14,10])

#assemble matrix A
A = np.vstack([x,np.ones(len(x))]).T

#turn Y into coulm vector I

y = y[:,np.newaxis]

#Direct least square regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)

#plot the data the regression line

plt.figure(figsize=(10,8))
plt.plot(x,y,'b.', label = 'Data')
plt.plot(x,alpha[0]*x + alpha[1], 'r', label = 'Fit')
plt.xlabel('x')
plt.ylabel('y')
for i, j in zip(x, y):
  plt.text(i, j, '({:.0f},{:.0f})'.format(float(i), float(j)))

plt.show()
# Out:
# [[ 2.00000000e+00]
#  [-3.55271368e-15]]
# <ipython-input-40-b130b8c114c6>:29: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(i, j, '({:.0f},{:.0f})'.format(float(i), float(j)))
